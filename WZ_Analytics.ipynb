# %% [markdown]
# <a href="https://colab.research.google.com/github/lmEshoo/wz-analytics/blob/main/WZ_Analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *****UPLOAD SUMMARY.CSV****

# %%
# !pip install plotly==4.14.3
# Out:
# Requirement already satisfied: plotly==4.14.3 in /usr/local/lib/python3.6/dist-packages (4.14.3)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from plotly==4.14.3) (1.15.0)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.6/dist-packages (from plotly==4.14.3) (1.3.3)

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.io as pio
import plotly.express as px
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from datetime import datetime
import plotly.express as px

# %%
def plot_xy(df, x_col, y_cols, anno=False, title='...'):

    fig = go.Figure()
    
    for y_col in y_cols:
        trace = go.Scattergl(
            x = df.datetime,
            y = df[y_col],
            mode = 'markers',
            name = y_col
        )
        fig.add_trace(trace)

    fig.update_layout(
        title=title,
        xaxis_title=x_col,
        hovermode='x')
    fig.update_yaxes(categoryorder="category ascending")
    fig.show()

def plot_xy_p(df, x_col, y_cols, anno=False, title='...'):

    fig = px.scatter(df, x=df.datetime, y='cod_tracker_match_placement', color="sbmm_match_difficulty",
                    size='cod_tracker_kills', title=title, hover_data=final_json_columns)
    fig.update_layout(yaxis=dict(type='linear',categoryorder='max descending', autorange='reversed'))
    fig.show()

# %% [markdown]
# # Load csv

# %%
filename_summary = './summary.csv'

# %%
df = pd.read_csv(filename_summary)

# %%
final_json_columns = ['cod_tracker_mode', 'cod_tracker_match_placement', 'cod_tracker_kills', 'cod_tracker_damage', 'sbmm_match_difficulty', 'sbmm_avg_kd', 'sbmm_median_kd']
df['datetime'] = pd.to_datetime(df['cod_tracker_date'] + ' ' + df['cod_tracker_time'],  format='%b %d %I:%M %p')
df['cod_tracker_match_placement'] = df['cod_tracker_match_placement'].map(lambda x: str(x)[:-2])
df['cod_tracker_match_placement'] = pd.to_numeric(df['cod_tracker_match_placement'])
df
# Out:
#      cod_tracker_games_per_day  ...            datetime
# 0                           11  ... 1900-01-12 23:56:00
# 1                           11  ... 1900-01-12 23:33:00
# 2                           11  ... 1900-01-12 23:00:00
# 3                           11  ... 1900-01-12 22:33:00
# 4                           11  ... 1900-01-12 22:04:00
# ..                         ...  ...                 ...
# 151                         10  ... 1900-01-02 22:57:00
# 152                         10  ... 1900-01-02 22:33:00
# 153                         10  ... 1900-01-02 22:29:00
# 154                         10  ... 1900-01-02 00:54:00
# 155                         10  ... 1900-01-02 00:23:00
#
# [156 rows x 12 columns]

# %% [markdown]
# ### Plot with scatter

# %%
plot_xy(df, 'datetime', final_json_columns, " ")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="6f8aa070-b5a1-4f11-b06f-1f4261fb032e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6f8aa070-b5a1-4f11-b06f-1f4261fb032e")) {                    Plotly.newPlot(                        "6f8aa070-b5a1-4f11-b06f-1f4261fb032e",                        [{"mode": "markers", "name": "cod_tracker_mode", "type": "scattergl", "x": ["1900-01-12T23:56:00", "1900-01-12T23:33:00", "1900-01-12T23:00:00", "1900-01-12T22:33:00", "1900-01-12T22:04:00", "1900-01-12T21:54:00", "1900-01-12T21:43:00", "1900-01-12T21:28:00", "1900-01-12T21:15:00", "1900-01-12T20:56:00", "1900-01-12T20:43:00", "1900-01-11T23:54:00", "1900-01-11T23:47:00", "1900-01-11T23:35:00", "1900-01-11T23:25:00", "1900-01-11T23:18:00", "1900-01-11T23:02:00", "1900-01-11T22:51:00", "1900-01-11T22:46:00", "1900-01-11T22:36:00", "1900-01-11T22:25:00", "1900-01-11T22:12:00", "1900-01-11T21:58:00", "1900-01-11T21:46:00", "1900-01-11T21:38:00", "1900-01-11T00:28:00", "1900-01-11T00:24:00", "1900-01-10T23:59:00", "1900-01-10T23:28:00", "1900-01-10T23:20:00", "1900-01-10T23:05:00", "1900-01-10T22:36:00", "1900-01-10T22:22:00", "1900-01-10T22:08:00", "1900-01-10T22:00:00", "1900-01-10T21:50:00", "1900-01-10T21:34:00", "1900-01-10T21:31:00", "1900-01-10T21:25:00", "1900-01-10T21:01:00", "1900-01-10T20:14:00", "1900-01-10T19:54:00", "1900-01-10T19:34:00", "1900-01-10T18:01:00", "1900-01-10T17:51:00", "1900-01-10T17:43:00", "1900-01-10T17:38:00", "1900-01-10T17:26:00", "1900-01-10T17:11:00", "1900-01-10T00:43:00", "1900-01-10T00:34:00", "1900-01-10T00:21:00", "1900-01-09T23:58:00", "1900-01-09T23:47:00", "1900-01-09T23:25:00", "1900-01-09T23:15:00", "1900-01-09T23:08:00", "1900-01-09T22:54:00", "1900-01-09T22:44:00", "1900-01-09T22:30:00", "1900-01-09T22:14:00", "1900-01-09T22:05:00", "1900-01-09T21:48:00", "1900-01-09T21:42:00", "1900-01-08T21:11:00", "1900-01-08T21:07:00", "1900-01-08T20:48:00", "1900-01-08T20:20:00", "1900-01-08T20:02:00", "1900-01-08T19:48:00", "1900-01-08T18:31:00", "1900-01-08T18:27:00", "1900-01-08T18:23:00", "1900-01-08T18:17:00", "1900-01-08T18:06:00", "1900-01-08T17:58:00", "1900-01-08T17:27:00", "1900-01-08T01:11:00", "1900-01-08T01:06:00", "1900-01-08T01:02:00", "1900-01-08T00:09:00", "1900-01-07T23:50:00", "1900-01-07T23:46:00", "1900-01-07T23:40:00", "1900-01-07T23:33:00", "1900-01-07T23:13:00", "1900-01-07T22:59:00", "1900-01-07T22:45:00", "1900-01-07T22:28:00", "1900-01-07T22:14:00", "1900-01-07T22:07:00", "1900-01-07T22:02:00", "1900-01-07T21:54:00", "1900-01-07T21:48:00", "1900-01-07T21:43:00", "1900-01-06T21:47:00", "1900-01-06T21:14:00", "1900-01-06T21:04:00", "1900-01-06T20:58:00", "1900-01-06T20:52:00", "1900-01-06T20:31:00", "1900-01-06T00:36:00", "1900-01-06T00:18:00", "1900-01-06T00:15:00", "1900-01-05T23:48:00", "1900-01-05T23:20:00", "1900-01-05T22:53:00", "1900-01-05T22:39:00", "1900-01-05T22:14:00", "1900-01-04T23:14:00", "1900-01-04T23:00:00", "1900-01-04T22:50:00", "1900-01-04T22:40:00", "1900-01-04T22:23:00", "1900-01-04T22:14:00", "1900-01-04T22:06:00", "1900-01-04T21:57:00", "1900-01-04T21:48:00", "1900-01-04T21:23:00", "1900-01-04T21:20:00", "1900-01-04T21:03:00", "1900-01-04T20:52:00", "1900-01-04T20:48:00", "1900-01-04T20:32:00", "1900-01-04T20:24:00", "1900-01-03T23:56:00", "1900-01-03T23:45:00", "1900-01-03T23:32:00", "1900-01-03T23:23:00", "1900-01-03T23:12:00", "1900-01-03T23:07:00", "1900-01-03T22:54:00", "1900-01-03T22:40:00", "1900-01-03T22:26:00", "1900-01-03T22:17:00", "1900-01-03T22:04:00", "1900-01-03T21:59:00", "1900-01-03T21:53:00", "1900-01-03T21:49:00", "1900-01-03T21:37:00", "1900-01-03T21:25:00", "1900-01-03T01:07:00", "1900-01-03T00:54:00", "1900-01-03T00:44:00", "1900-01-03T00:22:00", "1900-01-03T00:15:00", "1900-01-02T23:58:0 ...

# %% [markdown]
# ### Plot with express

# %%
plot_xy_p(df, 'time', df.columns, ' ')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="b712b5c4-149a-4f6a-a729-98e06c25ec99" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b712b5c4-149a-4f6a-a729-98e06c25ec99")) {                    Plotly.newPlot(                        "b712b5c4-149a-4f6a-a729-98e06c25ec99",                        [{"customdata": [["BR Duos", 4, "2,109", "DIAMOND 1", 1.27, 1.24]], "hovertemplate": "sbmm_match_difficulty=%{customdata[3]}<br>datetime=%{x}<br>cod_tracker_match_placement=%{y}<br>cod_tracker_kills=%{customdata[1]}<br>cod_tracker_mode=%{customdata[0]}<br>cod_tracker_damage=%{customdata[2]}<br>sbmm_avg_kd=%{customdata[4]}<br>sbmm_median_kd=%{customdata[5]}<extra></extra>", "legendgroup": "DIAMOND 1", "marker": {"color": "#636efa", "size": [4], "sizemode": "area", "sizeref": 0.0275, "symbol": "circle"}, "mode": "markers", "name": "DIAMOND 1", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["1900-01-12T23:56:00"], "xaxis": "x", "y": [13], "yaxis": "y"}, {"customdata": [["BR Duos", 5, "1,553", "DIAMOND 4", 1.18, 1.16], ["BR Trios", 0, "111", "DIAMOND 4", 1.19, 1.18]], "hovertemplate": "sbmm_match_difficulty=%{customdata[3]}<br>datetime=%{x}<br>cod_tracker_match_placement=%{y}<br>cod_tracker_kills=%{customdata[1]}<br>cod_tracker_mode=%{customdata[0]}<br>cod_tracker_damage=%{customdata[2]}<br>sbmm_avg_kd=%{customdata[4]}<br>sbmm_median_kd=%{customdata[5]}<extra></extra>", "legendgroup": "DIAMOND 4", "marker": {"color": "#EF553B", "size": [5, 0], "sizemode": "area", "sizeref": 0.0275, "symbol": "circle"}, "mode": "markers", "name": "DIAMOND 4", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["1900-01-12T23:33:00", "1900-01-09T23:47:00"], "xaxis": "x", "y": [12, 34], "yaxis": "y"}, {"customdata": [["BR Quads", 4, "1,300", "SILVER 3", 1.29, 0.98], ["BR Quads", 0, "203", "SILVER 3", 0.92, 0.97], ["Rebirth Mini Royale Quads", 2, "59.52", "SILVER 3", 0.98, 0.98]], "hovertemplate": "sbmm_match_difficulty=%{customdata[3]}<br>datetime=%{x}<br>cod_tracker_match_placement=%{y}<br>cod_tracker_kills=%{customdata[1]}<br>cod_tracker_mode=%{customdata[0]}<br>cod_tracker_damage=%{customdata[2]}<br>sbmm_avg_kd=%{customdata[4]}<br>sbmm_median_kd=%{customdata[5]}<extra></extra>", "legendgroup": "SILVER 3", "marker": {"color": "#00cc96", "size": [4, 0, 2], "sizemode": "area", "sizeref": 0.0275, "symbol": "circle"}, "mode": "markers", "name": "SILVER 3", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["1900-01-12T23:00:00", "1900-01-08T17:27:00", "1900-01-04T21:03:00"], "xaxis": "x", "y": [2, 14, 7], "yaxis": "y"}, {"customdata": [["BR Quads", 1, "783", "SILVER 4", 0.94, 0.96], ["BR Trios", 2, "1,617", "SILVER 4", 0.97, 0.97], ["BR Trios", 4, "2,182", "SILVER 4", 0.91, 0.94], ["BR Trios", 1, "421", "SILVER 4", 0.96, 0.95], ["BR Trios", 0, "10.69", "SILVER 4", 0.98, 0.94], ["Rebirth Mini Royale Quads", 2, "121.55", "SILVER 4", 0.96, 0.95]], "hovertemplate": "sbmm_match_difficulty=%{customdata[3]}<br>datetime=%{x}<br>cod_tracker_match_placement=%{y}<br>cod_tracker_kills=%{customdata[1]}<br>cod_tracker_mode=%{customdata[0]}<br>cod_tracker_damage=%{customdata[2]}<br>sbmm_avg_kd=%{customdata[4]}<br>sbmm_median_kd=%{customdata[5]}<extra></extra>", "legendgroup": "SILVER 4", "marker": {"color": "#ab63fa", "size": [1, 2, 4, 1, 0, 2], "sizemode": "area", "sizeref": 0.0275, "symbol": "circle"}, "mode": "markers", "name": "SILVER 4", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["1900-01-12T22:33:00", "1900-01-10T21:01:00", "1900-01-10T20:14:00", "1900-01-06T00:18:00", "1900-01-03T00:15:00", "1900-01-02T23:26:00"], "xaxis": "x", "y": [10, 12, 7, 16, 44, 6], "yaxis": "y"}, {"customdata": [["BR Quads", 6, "3,911", "SILVER 5", 0.92, 0.94], ["BR Trios", 3, "2,708 ...

# %% [markdown]
# ### Plot Parallel Categories

# %%
fig = px.parallel_categories(df, dimensions=None
                             ,color="cod_tracker_kills"
                             , color_continuous_scale=px.colors.sequential.Oryel
                             , dimensions_max_cardinality=40)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="13b0e7bf-98cd-495d-952c-c05c34bed593" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("13b0e7bf-98cd-495d-952c-c05c34bed593")) {                    Plotly.newPlot(                        "13b0e7bf-98cd-495d-952c-c05c34bed593",                        [{"dimensions": [{"label": "cod_tracker_games_per_day", "values": [11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 9, 9, 9, 9, 9, 9, 9, 9, 9, 5, 5, 5, 5, 5, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10]}, {"label": "cod_tracker_date", "values": ["Jan 12", "Jan 12", "Jan 12", "Jan 12", "Jan 12", "Jan 12", "Jan 12", "Jan 12", "Jan 12", "Jan 12", "Jan 12", "Jan 11", "Jan 11", "Jan 11", "Jan 11", "Jan 11", "Jan 11", "Jan 11", "Jan 11", "Jan 11", "Jan 11", "Jan 11", "Jan 11", "Jan 11", "Jan 11", "Jan 11", "Jan 11", "Jan 10", "Jan 10", "Jan 10", "Jan 10", "Jan 10", "Jan 10", "Jan 10", "Jan 10", "Jan 10", "Jan 10", "Jan 10", "Jan 10", "Jan 10", "Jan 10", "Jan 10", "Jan 10", "Jan 10", "Jan 10", "Jan 10", "Jan 10", "Jan 10", "Jan 10", "Jan 10", "Jan 10", "Jan 10", "Jan 09", "Jan 09", "Jan 09", "Jan 09", "Jan 09", "Jan 09", "Jan 09", "Jan 09", "Jan 09", "Jan 09", "Jan 09", "Jan 09", "Jan 08", "Jan 08", "Jan 08", "Jan 08", "Jan 08", "Jan 08", "Jan 08", "Jan 08", "Jan 08", "Jan 08", "Jan 08", "Jan 08", "Jan 08", "Jan 08", "Jan 08", "Jan 08", "Jan 08", "Jan 07", "Jan 07", "Jan 07", "Jan 07", "Jan 07", "Jan 07", "Jan 07", "Jan 07", "Jan 07", "Jan 07", "Jan 07", "Jan 07", "Jan 07", "Jan 07", "Jan 06", "Jan 06", "Jan 06", "Jan 06", "Jan 06", "Jan 06", "Jan 06", "Jan 06", "Jan 06", "Jan 05", "Jan 05", "Jan 05", "Jan 05", "Jan 05", "Jan 04", "Jan 04", "Jan 04", "Jan 04", "Jan 04", "Jan 04", "Jan 04", "Jan 04", "Jan 04", "Jan 04", "Jan 04", "Jan 04", "Jan 04", "Jan 04", "Jan 04", "Jan 04", "Jan 03", "Jan 03", "Jan 03", "Jan 03", "Jan 03", "Jan 03", "Jan 03", "Jan 03", "Jan 03", "Jan 03", "Jan 03", "Jan 03", "Jan 03", "Jan 03", "Jan 03", "Jan 03", "Jan 03", "Jan 03", "Jan 03", "Jan 03", "Jan 03", "Jan 02", "Jan 02", "Jan 02", "Jan 02", "Jan 02", "Jan 02", "Jan 02", "Jan 02", "Jan 02", "Jan 02"]}, {"label": "cod_tracker_mode", "values": ["BR Duos", "BR Duos", "BR Quads", "BR Quads", "BR Quads", "Resurgence Trios", "Resurgence Trios", "Resurgence Trios", "Resurgence Trios", "Resurgence Trios", "Rebirth Mini Royale Duos", "Rebirth Mini Royale Duos", "Rebirth Mini Royale Duos", "Rebirth Mini Royale Duos", "Rebirth Mini Royale Duos", "Rebirth Mini Royale Duos", "Rebirth Mini Royale Duos", "Rebirth Mini Royale Duos", "Rebirth Mini Royale Duos", "Rebirth Mini Royale Duos", "Rebirth Mini Royale Duos", "Rebirth Mini Royale Duos", "Rebirth Mini Royale Duos", "Rebirth Mini Royale Duos", "Rebirth Mini Royale Duos", "Resurgence Trios", "Resurgence Trios", "BR Trios", "BR Trios", "BR Trios", "BR Trios", "BR Trios", "BR Trios", "Resurgence Trios", "BR Trios", "Resurgence Trios", "Resurgence Trios", "Resurgence Trios", "Resurgence Trios", "BR Trios", "BR Trios", "BR Duos", "BR Duos", "Resurgence Trios", "Resurgence Trios", "Resurgence Trios", "Resurgence Trios", "Resurgence Trios", "Resurgence Trios", "Rebirth Mini Royale Duos", "Rebirth Mini Royale Duos", "Rebirth Mini Royale Duos", "BR Trios", "BR Trios", "BR Trios", "BR Trios", "Resurgence Trios", "Resurgenc ...
